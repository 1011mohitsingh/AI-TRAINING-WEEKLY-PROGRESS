# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", temperature=0)

# %%
# crate a state 
class LLMState(TypedDict):
    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:
    # extract the question from state
    question = state['question']

    # form a prompt
    prompt = f'Answer the following question: {question}'

    #ask the question to the llm 
    answer = model.invoke(prompt).content

    # update the answer in the state
    state['answer'] = answer
    
    return state

# %%
# create our graph
graph = StateGraph(LLMState)

# add a node to the graph
graph.add_node('llm_qa',llm_qa)

# add edges
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

# compile
workflow = graph.compile()

# %%
# execute

initial_state = {'question':'How far is moon from the earth?'}
final_state = workflow.invoke(initial_state)

print(final_state['answer'])
# Out:
# The distance between the Earth and the Moon is not constant. It varies because the Moon's orbit around the Earth is not a perfect circle, but rather an ellipse.
#
# Here's a breakdown of the distances:
#
# *   **Average Distance:** The average distance between the Earth and the Moon is approximately **384,400 kilometers (238,900 miles)**.
#
# *   **Perigee (Closest Point):** When the Moon is closest to Earth, it's at its perigee. This distance is about **363,300 kilometers (225,700 miles)**.
#
# *   **Apogee (Farthest Point):** When the Moon is farthest from Earth, it's at its apogee. This distance is about **405,500 kilometers (251,900 miles)**.
#
# So, while the **average distance is the most commonly cited figure**, it's important to remember that the actual distance fluctuates.
