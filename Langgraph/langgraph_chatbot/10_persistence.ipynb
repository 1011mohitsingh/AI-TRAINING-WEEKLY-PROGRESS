# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()
llm = ChatGoogleGenerativeAI(model = "gemini-2.5-flash")

# %%
class JokeState(TypedDict):
    topic:str
    joke:str
    explanation:str

# %%
def generate_joke(state: JokeState):
    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):
    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content
    return {'explanation': response}

# %%
graph = StateGraph(JokeState)
graph.add_node('generate_joke',generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()
workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable":{"thread_id":1}}
workflow.invoke({'topic':'pizza'}, config = config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza get a job?\nBecause it kneaded the dough!',
#  'explanation': 'This joke is a pun that plays on the similar sound of two phrases:\n\n1.  **"Kneaded the dough" (literal pizza making):**\n    *   **"Kneaded"** (pronounced "need-ed") refers to the physical act of working and pressing pizza dough with your hands to develop its texture.\n    *   **"Dough"** is the raw mixture that makes up the pizza crust.\n    *   So, a pizza literally "kneads its dough" when it\'s being made.\n\n2.  **"Needed the dough" (slang for needing money):**\n    *   **"Needed"** (sounds exactly like "kneaded") means to require something.\n    *   **"Dough"** is a common slang term for **money**.\n    *   So, if someone "needed the dough," it means they needed money.\n\n**The Punchline Explained:**\n\nThe joke asks "Why did the pizza get a job?" Jobs are for earning money. The answer, "Because it kneaded the dough," sounds like "Because it *needed the money*." The humor comes from the unexpected twist of applying a literal pizza-making term to a very human reason for getting a job, using the wordplay between "kneaded" and "needed," and "dough" (pizza) and "dough" (money).'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\nBecause it kneaded the dough!', 'explanation': 'This joke is a pun that plays on the similar sound of two phrases:\n\n1.  **"Kneaded the dough" (literal pizza making):**\n    *   **"Kneaded"** (pronounced "need-ed") refers to the physical act of working and pressing pizza dough with your hands to develop its texture.\n    *   **"Dough"** is the raw mixture that makes up the pizza crust.\n    *   So, a pizza literally "kneads its dough" when it\'s being made.\n\n2.  **"Needed the dough" (slang for needing money):**\n    *   **"Needed"** (sounds exactly like "kneaded") means to require something.\n    *   **"Dough"** is a common slang term for **money**.\n    *   So, if someone "needed the dough," it means they needed money.\n\n**The Punchline Explained:**\n\nThe joke asks "Why did the pizza get a job?" Jobs are for earning money. The answer, "Because it kneaded the dough," sounds like "Because it *needed the money*." The humor comes from the unexpected twist of applying a literal pizza-making term to a very human reason for getting a job, using the wordplay between "kneaded" and "needed," and "dough" (pizza) and "dough" (money).'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c4-3224-6a2a-8004-b95345a76ef5'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-06-08T11:21:58.122756+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-f591-619c-8003-36c94e13dd93'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\nBecause it kneaded the dough!', 'explanation': 'This joke is a pun that plays on the similar sound of two phrases:\n\n1.  **"Kneaded the dough" (literal pizza making):**\n    *   **"Kneaded"** (pronounced "need-ed") refers to the physical act of working and pressing pizza dough with your hands to develop its texture.\n    *   **"Dough"** is the raw mixture that makes up the pizza crust.\n    *   So, a pizza literally "kneads its dough" when it\'s being made.\n\n2.  **"Needed the dough" (slang for needing money):**\n    *   **"Needed"** (sounds exactly like "kneaded") means to require something.\n    *   **"Dough"** is a common slang term for **money**.\n    *   So, if someone "needed the dough," it means they needed money.\n\n**The Punchline Explained:**\n\nThe joke asks "Why did the pizza get a job?" Jobs are for earning money. The answer, "Because it kneaded the dough," sounds like "Because it *needed the money*." The humor comes from the unexpected twist of applying a literal pizza-making term to a very human reason for getting a job, using the wordplay between "kneaded" and "needed," and "dough" (pizza) and "dough" (money).'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c4-3224-6a2a-8004-b95345a76ef5'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-06-08T11:21:58.122756+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-f591-619c-8003-36c94e13dd93'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\nBecause it kneaded the dough!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-f591-619c-8003-36c94e13dd93'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-06-08T11:21:51.770870+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aaa-69a5-8002-b6c8e82bc627'}}, tasks=(PregelTask(id='693dcb1e-7879-fb5d-c5e8-e3c568430693', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a pun that plays on the similar sound of two phrases:\n\n1.  **"Kneaded the dough" (literal pizza making):**\n    *   **"Kneaded"** (pronounced "need-ed") refers to the physical act of working and pressing pizza dough with your hands to develop its texture.\n    *   **"Dough"** is the raw mixture that makes up the pizza crust.\n    *   So, a pizza literally "kneads its dough" when it\'s being made.\n\n2.  **"Needed the dough" (slang for needing money):**\n    *   **"Needed"** (sounds exactly like "kneaded") means to require something.\n    *   **"Dough"** is a common slang term for **money**.\n    *   So, if someone "needed the dough," it means they needed money.\n\n**The Punchline Explained:**\n\nThe joke asks "Why did the pizza get a job?" Jobs are for earning money. The answer, "Because it kneaded the dough," sounds like "Because it *needed the money*." The humor comes from the unexpected twist of applying a literal pizza-making term to a very human reason for getting a job, using the wordplay between "kneaded" and "needed," and "dough" (pizza) and "dough" (money).'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aaa-69a5-8002-b6c8e82bc627'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-06-08T11:21:42.239274+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aa4-6c48-8001-ac7f09cff08d'}}, tasks=(PregelTask(id='dc527f0b-8538-02be-6a9d-a0bd93250f30', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza get a job?\nBecause it kneaded the dough!'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aa4-6c48-8001-ac7f09cff08d'}}, metadata={'source': 'input', 'step': 1, 'parents': {}}, created_at='2026-06-08T11:21:42.236884+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c1-b488-638e-8000-27d7116c585a'}}, tasks=(PregelTask(id='f93b3b1a-8278-9415-0952-41923b4320ef', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c1-b488-638e-8000-27d7116c585a'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-06-08T11:20:51.264398+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c1-b483-653e-bfff-3bd1f78a4f51'}}, tasks=(PregelTask(id='d17fdd74-3868-56db-21db-91a1b206877c', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error="ConnectError('[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)')", interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c1-b483-653e-bfff-3bd1f78a4f51'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-06-08T11:20:51.262393+00:00', parent_config=None, tasks=(PregelTask(id='a270c772-0242-cd1c-6d97-3f4c32f5bd98', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
config2 = {"configurable":{"thread_id":"2"}}
workflow.invoke({'topic':'pasta'}, config= config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'What do you call a fake noodle?\n\nAn **impasta**!',
#  'explanation': 'This is a pun, a type of joke that plays on words that sound alike but have different meanings.\n\nHere\'s the breakdown:\n\n1.  **"Impasta"** sounds almost exactly like **"imposter"**.\n2.  An **imposter** is someone who pretends to be someone else, or something that is fake or not genuine.\n3.  **Pasta** is a type of food, often made into various shapes, including noodles.\n\nSo, the joke takes the idea of a "fake" (like an imposter) and applies it to "noodles" (pasta). By changing "imposter" slightly to "impasta," the joke creates a clever word that both means "fake" (like an imposter) and refers to "noodles" (pasta).\n\nA "fake noodle" is, therefore, an "impasta" – a funny play on words!'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\nBecause it kneaded the dough!', 'explanation': 'This joke is a pun that plays on the similar sound of two phrases:\n\n1.  **"Kneaded the dough" (literal pizza making):**\n    *   **"Kneaded"** (pronounced "need-ed") refers to the physical act of working and pressing pizza dough with your hands to develop its texture.\n    *   **"Dough"** is the raw mixture that makes up the pizza crust.\n    *   So, a pizza literally "kneads its dough" when it\'s being made.\n\n2.  **"Needed the dough" (slang for needing money):**\n    *   **"Needed"** (sounds exactly like "kneaded") means to require something.\n    *   **"Dough"** is a common slang term for **money**.\n    *   So, if someone "needed the dough," it means they needed money.\n\n**The Punchline Explained:**\n\nThe joke asks "Why did the pizza get a job?" Jobs are for earning money. The answer, "Because it kneaded the dough," sounds like "Because it *needed the money*." The humor comes from the unexpected twist of applying a literal pizza-making term to a very human reason for getting a job, using the wordplay between "kneaded" and "needed," and "dough" (pizza) and "dough" (money).'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c4-3224-6a2a-8004-b95345a76ef5'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-06-08T11:21:58.122756+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-f591-619c-8003-36c94e13dd93'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\nBecause it kneaded the dough!', 'explanation': 'This joke is a pun that plays on the similar sound of two phrases:\n\n1.  **"Kneaded the dough" (literal pizza making):**\n    *   **"Kneaded"** (pronounced "need-ed") refers to the physical act of working and pressing pizza dough with your hands to develop its texture.\n    *   **"Dough"** is the raw mixture that makes up the pizza crust.\n    *   So, a pizza literally "kneads its dough" when it\'s being made.\n\n2.  **"Needed the dough" (slang for needing money):**\n    *   **"Needed"** (sounds exactly like "kneaded") means to require something.\n    *   **"Dough"** is a common slang term for **money**.\n    *   So, if someone "needed the dough," it means they needed money.\n\n**The Punchline Explained:**\n\nThe joke asks "Why did the pizza get a job?" Jobs are for earning money. The answer, "Because it kneaded the dough," sounds like "Because it *needed the money*." The humor comes from the unexpected twist of applying a literal pizza-making term to a very human reason for getting a job, using the wordplay between "kneaded" and "needed," and "dough" (pizza) and "dough" (money).'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c4-3224-6a2a-8004-b95345a76ef5'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-06-08T11:21:58.122756+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-f591-619c-8003-36c94e13dd93'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\nBecause it kneaded the dough!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-f591-619c-8003-36c94e13dd93'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-06-08T11:21:51.770870+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aaa-69a5-8002-b6c8e82bc627'}}, tasks=(PregelTask(id='693dcb1e-7879-fb5d-c5e8-e3c568430693', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a pun that plays on the similar sound of two phrases:\n\n1.  **"Kneaded the dough" (literal pizza making):**\n    *   **"Kneaded"** (pronounced "need-ed") refers to the physical act of working and pressing pizza dough with your hands to develop its texture.\n    *   **"Dough"** is the raw mixture that makes up the pizza crust.\n    *   So, a pizza literally "kneads its dough" when it\'s being made.\n\n2.  **"Needed the dough" (slang for needing money):**\n    *   **"Needed"** (sounds exactly like "kneaded") means to require something.\n    *   **"Dough"** is a common slang term for **money**.\n    *   So, if someone "needed the dough," it means they needed money.\n\n**The Punchline Explained:**\n\nThe joke asks "Why did the pizza get a job?" Jobs are for earning money. The answer, "Because it kneaded the dough," sounds like "Because it *needed the money*." The humor comes from the unexpected twist of applying a literal pizza-making term to a very human reason for getting a job, using the wordplay between "kneaded" and "needed," and "dough" (pizza) and "dough" (money).'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aaa-69a5-8002-b6c8e82bc627'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-06-08T11:21:42.239274+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aa4-6c48-8001-ac7f09cff08d'}}, tasks=(PregelTask(id='dc527f0b-8538-02be-6a9d-a0bd93250f30', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza get a job?\nBecause it kneaded the dough!'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aa4-6c48-8001-ac7f09cff08d'}}, metadata={'source': 'input', 'step': 1, 'parents': {}}, created_at='2026-06-08T11:21:42.236884+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c1-b488-638e-8000-27d7116c585a'}}, tasks=(PregelTask(id='f93b3b1a-8278-9415-0952-41923b4320ef', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c1-b488-638e-8000-27d7116c585a'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-06-08T11:20:51.264398+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c1-b483-653e-bfff-3bd1f78a4f51'}}, tasks=(PregelTask(id='d17fdd74-3868-56db-21db-91a1b206877c', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error="ConnectError('[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)')", interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c1-b483-653e-bfff-3bd1f78a4f51'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-06-08T11:20:51.262393+00:00', parent_config=None, tasks=(PregelTask(id='a270c772-0242-cd1c-6d97-3f4c32f5bd98', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %% [markdown]
# Time Travel

# %%
workflow.get_state({"configurable":{"thread_id":"1", "checkpoint_id": "1f06cc6e-7232-6cb1-8000-f71609e6cec5"}})
# Out:
# StateSnapshot(values={}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_id': '1f06cc6e-7232-6cb1-8000-f71609e6cec5'}}, metadata=None, created_at=None, parent_config=None, tasks=(), interrupts=())

# %%
workflow.invoke(None, {"configurable":{"thread_id":"1", "checkpoint_id":"1f1632c3-9aaa-69a5-8002-b6c8e82bc627"}})
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza maker break up with the cheese?\n\nBecause he thought it was too *cheesy*!',
#  'explanation': 'This joke is a classic example of a **pun**, which relies on a word having two different meanings.\n\nHere\'s the breakdown:\n\n1.  **Meaning 1 (Literal - related to pizza):** When we talk about food, "cheesy" literally means something contains a lot of cheese or has a strong cheese flavor. A pizza maker would definitely deal with a lot of literal cheese.\n\n2.  **Meaning 2 (Figurative/Slang):** "Cheesy" is also a slang term used to describe something that is corny, unoriginal, overly sentimental, tacky, or trying too hard to be funny or impressive (often in a cringey way).\n\n**How the joke works:**\n\n*   The setup ("Why did the pizza maker break up with the cheese?") makes you think about the *literal* cheese used on a pizza. You expect a reason related to its taste, texture, or quantity.\n*   The punchline ("Because he thought it was too *cheesy*!") uses the *slang* meaning. The humor comes from the unexpected twist of applying a human characteristic (being "corny" or "tacky") to an inanimate object like cheese, as if the cheese itself had a personality that was annoying or unoriginal.\n\nSo, the joke is funny because it plays on the double meaning of "cheesy," tricking your brain into expecting one meaning and then delivering the punchline with the other.'}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza maker break up with the cheese?\n\nBecause he thought it was too *cheesy*!', 'explanation': 'This joke is a classic example of a **pun**, which relies on a word having two different meanings.\n\nHere\'s the breakdown:\n\n1.  **Meaning 1 (Literal - related to pizza):** When we talk about food, "cheesy" literally means something contains a lot of cheese or has a strong cheese flavor. A pizza maker would definitely deal with a lot of literal cheese.\n\n2.  **Meaning 2 (Figurative/Slang):** "Cheesy" is also a slang term used to describe something that is corny, unoriginal, overly sentimental, tacky, or trying too hard to be funny or impressive (often in a cringey way).\n\n**How the joke works:**\n\n*   The setup ("Why did the pizza maker break up with the cheese?") makes you think about the *literal* cheese used on a pizza. You expect a reason related to its taste, texture, or quantity.\n*   The punchline ("Because he thought it was too *cheesy*!") uses the *slang* meaning. The humor comes from the unexpected twist of applying a human characteristic (being "corny" or "tacky") to an inanimate object like cheese, as if the cheese itself had a personality that was annoying or unoriginal.\n\nSo, the joke is funny because it plays on the double meaning of "cheesy," tricking your brain into expecting one meaning and then delivering the punchline with the other.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632d8-63d4-653c-8005-45330c43005e'}}, metadata={'source': 'loop', 'step': 5, 'parents': {}}, created_at='2026-06-08T11:31:00.203654+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632d8-1e86-6bab-8004-64060f6e662c'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza maker break up with the cheese?\n\nBecause he thought it was too *cheesy*!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632d8-1e86-6bab-8004-64060f6e662c'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-06-08T11:30:52.936695+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632d6-bd43-6dd0-8003-791f938d2665'}}, tasks=(PregelTask(id='8dc5c706-e56e-f804-874f-775b01ff26a6', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a classic example of a **pun**, which relies on a word having two different meanings.\n\nHere\'s the breakdown:\n\n1.  **Meaning 1 (Literal - related to pizza):** When we talk about food, "cheesy" literally means something contains a lot of cheese or has a strong cheese flavor. A pizza maker would definitely deal with a lot of literal cheese.\n\n2.  **Meaning 2 (Figurative/Slang):** "Cheesy" is also a slang term used to describe something that is corny, unoriginal, overly sentimental, tacky, or trying too hard to be funny or impressive (often in a cringey way).\n\n**How the joke works:**\n\n*   The setup ("Why did the pizza maker break up with the cheese?") makes you think about the *literal* cheese used on a pizza. You expect a reason related to its taste, texture, or quantity.\n*   The punchline ("Because he thought it was too *cheesy*!") uses the *slang* meaning. The humor comes from the unexpected twist of applying a human characteristic (being "corny" or "tacky") to an inanimate object like cheese, as if the cheese itself had a personality that was annoying or unoriginal.\n\nSo, the joke is funny because it plays on the double meaning of "cheesy," tricking your brain into expecting one meaning and then delivering the punchline with the other.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632d6-bd43-6dd0-8003-791f938d2665'}}, metadata={'source': 'fork', 'step': 3, 'parents': {}}, created_at='2026-06-08T11:30:15.894574+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aaa-69a5-8002-b6c8e82bc627'}}, tasks=(PregelTask(id='66c59019-2594-d0ab-6886-37901855e94c', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza maker break up with the cheese?\n\nBecause he thought it was too *cheesy*!'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\nBecause it kneaded the dough!', 'explanation': 'This joke is a pun that plays on the similar sound of two phrases:\n\n1.  **"Kneaded the dough" (literal pizza making):**\n    *   **"Kneaded"** (pronounced "need-ed") refers to the physical act of working and pressing pizza dough with your hands to develop its texture.\n    *   **"Dough"** is the raw mixture that makes up the pizza crust.\n    *   So, a pizza literally "kneads its dough" when it\'s being made.\n\n2.  **"Needed the dough" (slang for needing money):**\n    *   **"Needed"** (sounds exactly like "kneaded") means to require something.\n    *   **"Dough"** is a common slang term for **money**.\n    *   So, if someone "needed the dough," it means they needed money.\n\n**The Punchline Explained:**\n\nThe joke asks "Why did the pizza get a job?" Jobs are for earning money. The answer, "Because it kneaded the dough," sounds like "Because it *needed the money*." The humor comes from the unexpected twist of applying a literal pizza-making term to a very human reason for getting a job, using the wordplay between "kneaded" and "needed," and "dough" (pizza) and "dough" (money).'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c4-3224-6a2a-8004-b95345a76ef5'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-06-08T11:21:58.122756+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-f591-619c-8003-36c94e13dd93'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\nBecause it kneaded the dough!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-f591-619c-8003-36c94e13dd93'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-06-08T11:21:51.770870+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aaa-69a5-8002-b6c8e82bc627'}}, tasks=(PregelTask(id='693dcb1e-7879-fb5d-c5e8-e3c568430693', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a pun that plays on the similar sound of two phrases:\n\n1.  **"Kneaded the dough" (literal pizza making):**\n    *   **"Kneaded"** (pronounced "need-ed") refers to the physical act of working and pressing pizza dough with your hands to develop its texture.\n    *   **"Dough"** is the raw mixture that makes up the pizza crust.\n    *   So, a pizza literally "kneads its dough" when it\'s being made.\n\n2.  **"Needed the dough" (slang for needing money):**\n    *   **"Needed"** (sounds exactly like "kneaded") means to require something.\n    *   **"Dough"** is a common slang term for **money**.\n    *   So, if someone "needed the dough," it means they needed money.\n\n**The Punchline Explained:**\n\nThe joke asks "Why did the pizza get a job?" Jobs are for earning money. The answer, "Because it kneaded the dough," sounds like "Because it *needed the money*." The humor comes from the unexpected twist of applying a literal pizza-making term to a very human reason for getting a job, using the wordplay between "kneaded" and "needed," and "dough" (pizza) and "dough" (money).'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aaa-69a5-8002-b6c8e82bc627'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-06-08T11:21:42.239274+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aa4-6c48-8001-ac7f09cff08d'}}, tasks=(PregelTask(id='dc527f0b-8538-02be-6a9d-a0bd93250f30', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza get a job?\nBecause it kneaded the dough!'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aa4-6c48-8001-ac7f09cff08d'}}, metadata={'source': 'input', 'step': 1, 'parents': {}}, created_at='2026-06-08T11:21:42.236884+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c1-b488-638e-8000-27d7116c585a'}}, tasks=(PregelTask(id='f93b3b1a-8278-9415-0952-41923b4320ef', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c1-b488-638e-8000-27d7116c585a'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-06-08T11:20:51.264398+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c1-b483-653e-bfff-3bd1f78a4f51'}}, tasks=(PregelTask(id='d17fdd74-3868-56db-21db-91a1b206877c', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error="ConnectError('[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)')", interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c1-b483-653e-bfff-3bd1f78a4f51'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-06-08T11:20:51.262393+00:00', parent_config=None, tasks=(PregelTask(id='a270c772-0242-cd1c-6d97-3f4c32f5bd98', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %% [markdown]
# Updating state

# %%
workflow.update_state({"configurable":{"thread_id":"1", "checkpoint_id":"1f06cc6e-7232-6cb1-8000-f71609e6cec5", "checkpoint_ns":""}}, {'topic':'samosa'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f1632dc-b80a-6ffa-8000-a63969dc4c6b'}}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632dc-b80a-6ffa-8000-a63969dc4c6b'}}, metadata={'source': 'update', 'step': 0, 'parents': {}}, created_at='2026-06-08T11:32:56.408268+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f06cc6e-7232-6cb1-8000-f71609e6cec5'}}, tasks=(PregelTask(id='7fbb4eba-114d-13ef-1c74-d98ff00dffc5', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza maker break up with the cheese?\n\nBecause he thought it was too *cheesy*!', 'explanation': 'This joke is a classic example of a **pun**, which relies on a word having two different meanings.\n\nHere\'s the breakdown:\n\n1.  **Meaning 1 (Literal - related to pizza):** When we talk about food, "cheesy" literally means something contains a lot of cheese or has a strong cheese flavor. A pizza maker would definitely deal with a lot of literal cheese.\n\n2.  **Meaning 2 (Figurative/Slang):** "Cheesy" is also a slang term used to describe something that is corny, unoriginal, overly sentimental, tacky, or trying too hard to be funny or impressive (often in a cringey way).\n\n**How the joke works:**\n\n*   The setup ("Why did the pizza maker break up with the cheese?") makes you think about the *literal* cheese used on a pizza. You expect a reason related to its taste, texture, or quantity.\n*   The punchline ("Because he thought it was too *cheesy*!") uses the *slang* meaning. The humor comes from the unexpected twist of applying a human characteristic (being "corny" or "tacky") to an inanimate object like cheese, as if the cheese itself had a personality that was annoying or unoriginal.\n\nSo, the joke is funny because it plays on the double meaning of "cheesy," tricking your brain into expecting one meaning and then delivering the punchline with the other.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632d8-63d4-653c-8005-45330c43005e'}}, metadata={'source': 'loop', 'step': 5, 'parents': {}}, created_at='2026-06-08T11:31:00.203654+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632d8-1e86-6bab-8004-64060f6e662c'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza maker break up with the cheese?\n\nBecause he thought it was too *cheesy*!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632d8-1e86-6bab-8004-64060f6e662c'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-06-08T11:30:52.936695+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632d6-bd43-6dd0-8003-791f938d2665'}}, tasks=(PregelTask(id='8dc5c706-e56e-f804-874f-775b01ff26a6', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a classic example of a **pun**, which relies on a word having two different meanings.\n\nHere\'s the breakdown:\n\n1.  **Meaning 1 (Literal - related to pizza):** When we talk about food, "cheesy" literally means something contains a lot of cheese or has a strong cheese flavor. A pizza maker would definitely deal with a lot of literal cheese.\n\n2.  **Meaning 2 (Figurative/Slang):** "Cheesy" is also a slang term used to describe something that is corny, unoriginal, overly sentimental, tacky, or trying too hard to be funny or impressive (often in a cringey way).\n\n**How the joke works:**\n\n*   The setup ("Why did the pizza maker break up with the cheese?") makes you think about the *literal* cheese used on a pizza. You expect a reason related to its taste, texture, or quantity.\n*   The punchline ("Because he thought it was too *cheesy*!") uses the *slang* meaning. The humor comes from the unexpected twist of applying a human characteristic (being "corny" or "tacky") to an inanimate object like cheese, as if the cheese itself had a personality that was annoying or unoriginal.\n\nSo, the joke is funny because it plays on the double meaning of "cheesy," tricking your brain into expecting one meaning and then delivering the punchline with the other.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632d6-bd43-6dd0-8003-791f938d2665'}}, metadata={'source': 'fork', 'step': 3, 'parents': {}}, created_at='2026-06-08T11:30:15.894574+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aaa-69a5-8002-b6c8e82bc627'}}, tasks=(PregelTask(id='66c59019-2594-d0ab-6886-37901855e94c', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza maker break up with the cheese?\n\nBecause he thought it was too *cheesy*!'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\nBecause it kneaded the dough!', 'explanation': 'This joke is a pun that plays on the similar sound of two phrases:\n\n1.  **"Kneaded the dough" (literal pizza making):**\n    *   **"Kneaded"** (pronounced "need-ed") refers to the physical act of working and pressing pizza dough with your hands to develop its texture.\n    *   **"Dough"** is the raw mixture that makes up the pizza crust.\n    *   So, a pizza literally "kneads its dough" when it\'s being made.\n\n2.  **"Needed the dough" (slang for needing money):**\n    *   **"Needed"** (sounds exactly like "kneaded") means to require something.\n    *   **"Dough"** is a common slang term for **money**.\n    *   So, if someone "needed the dough," it means they needed money.\n\n**The Punchline Explained:**\n\nThe joke asks "Why did the pizza get a job?" Jobs are for earning money. The answer, "Because it kneaded the dough," sounds like "Because it *needed the money*." The humor comes from the unexpected twist of applying a literal pizza-making term to a very human reason for getting a job, using the wordplay between "kneaded" and "needed," and "dough" (pizza) and "dough" (money).'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c4-3224-6a2a-8004-b95345a76ef5'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-06-08T11:21:58.122756+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-f591-619c-8003-36c94e13dd93'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\nBecause it kneaded the dough!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-f591-619c-8003-36c94e13dd93'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-06-08T11:21:51.770870+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aaa-69a5-8002-b6c8e82bc627'}}, tasks=(PregelTask(id='693dcb1e-7879-fb5d-c5e8-e3c568430693', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a pun that plays on the similar sound of two phrases:\n\n1.  **"Kneaded the dough" (literal pizza making):**\n    *   **"Kneaded"** (pronounced "need-ed") refers to the physical act of working and pressing pizza dough with your hands to develop its texture.\n    *   **"Dough"** is the raw mixture that makes up the pizza crust.\n    *   So, a pizza literally "kneads its dough" when it\'s being made.\n\n2.  **"Needed the dough" (slang for needing money):**\n    *   **"Needed"** (sounds exactly like "kneaded") means to require something.\n    *   **"Dough"** is a common slang term for **money**.\n    *   So, if someone "needed the dough," it means they needed money.\n\n**The Punchline Explained:**\n\nThe joke asks "Why did the pizza get a job?" Jobs are for earning money. The answer, "Because it kneaded the dough," sounds like "Because it *needed the money*." The humor comes from the unexpected twist of applying a literal pizza-making term to a very human reason for getting a job, using the wordplay between "kneaded" and "needed," and "dough" (pizza) and "dough" (money).'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aaa-69a5-8002-b6c8e82bc627'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-06-08T11:21:42.239274+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aa4-6c48-8001-ac7f09cff08d'}}, tasks=(PregelTask(id='dc527f0b-8538-02be-6a9d-a0bd93250f30', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza get a job?\nBecause it kneaded the dough!'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aa4-6c48-8001-ac7f09cff08d'}}, metadata={'source': 'input', 'step': 1, 'parents': {}}, created_at='2026-06-08T11:21:42.236884+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c1-b488-638e-8000-27d7116c585a'}}, tasks=(PregelTask(id='f93b3b1a-8278-9415-0952-41923b4320ef', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c1-b488-638e-8000-27d7116c585a'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-06-08T11:20:51.264398+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c1-b483-653e-bfff-3bd1f78a4f51'}}, tasks=(PregelTask(id='d17fdd74-3868-56db-21db-91a1b206877c', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error="ConnectError('[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)')", interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c1-b483-653e-bfff-3bd1f78a4f51'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-06-08T11:20:51.262393+00:00', parent_config=None, tasks=(PregelTask(id='a270c772-0242-cd1c-6d97-3f4c32f5bd98', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
workflow.invoke(None, {"configurable":{"thread_id":"1", "checkpoint_id":"1f1632dc-b80a-6ffa-8000-a63969dc4c6b"}})
# Out:
# {'topic': 'samosa',
#  'joke': 'Why are samosas so good at arguments?\n\nBecause they always have a **point**!',
#  'explanation': 'This joke is a pun, playing on the double meaning of the word "**point**."\n\nHere\'s the breakdown:\n\n1.  **"Good at arguments" and "having a point" (Meaning 1):** In the context of an argument or discussion, if someone "has a point," it means they have a valid, well-reasoned idea, a specific statement, or a strong reason to support their side. Someone who is "good at arguments" would consistently make good "points."\n\n2.  **"Samosas have a point" (Meaning 2):** Samosas are typically triangular in shape. Because of this shape, they literally have sharp or distinct **points** or corners.\n\n**The Humor:**\n\nThe joke sets you up to think about the intellectual meaning of "having a point" (a valid argument). The punchline then cleverly shifts to the literal, physical "points" of the triangular samosa, creating a surprising and silly connection between the food item and its argumentative prowess. It\'s a classic example of a pun, where the unexpected literal interpretation of a word creates the comedic effect.'}

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'samosa', 'joke': 'Why are samosas so good at arguments?\n\nBecause they always have a **point**!', 'explanation': 'This joke is a pun, playing on the double meaning of the word "**point**."\n\nHere\'s the breakdown:\n\n1.  **"Good at arguments" and "having a point" (Meaning 1):** In the context of an argument or discussion, if someone "has a point," it means they have a valid, well-reasoned idea, a specific statement, or a strong reason to support their side. Someone who is "good at arguments" would consistently make good "points."\n\n2.  **"Samosas have a point" (Meaning 2):** Samosas are typically triangular in shape. Because of this shape, they literally have sharp or distinct **points** or corners.\n\n**The Humor:**\n\nThe joke sets you up to think about the intellectual meaning of "having a point" (a valid argument). The punchline then cleverly shifts to the literal, physical "points" of the triangular samosa, creating a surprising and silly connection between the food item and its argumentative prowess. It\'s a classic example of a pun, where the unexpected literal interpretation of a word creates the comedic effect.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163308-3e04-6305-8002-929a811160da'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-06-08T11:52:24.727859+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163307-f9d1-68d1-8001-b6c3bf5f37a4'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'samosa', 'joke': 'Why are samosas so good at arguments?\n\nBecause they always have a **point**!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f163307-f9d1-68d1-8001-b6c3bf5f37a4'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-06-08T11:52:17.577800+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632dc-b80a-6ffa-8000-a63969dc4c6b'}}, tasks=(PregelTask(id='563f89e1-8a39-ade2-387f-55aaccd83452', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a pun, playing on the double meaning of the word "**point**."\n\nHere\'s the breakdown:\n\n1.  **"Good at arguments" and "having a point" (Meaning 1):** In the context of an argument or discussion, if someone "has a point," it means they have a valid, well-reasoned idea, a specific statement, or a strong reason to support their side. Someone who is "good at arguments" would consistently make good "points."\n\n2.  **"Samosas have a point" (Meaning 2):** Samosas are typically triangular in shape. Because of this shape, they literally have sharp or distinct **points** or corners.\n\n**The Humor:**\n\nThe joke sets you up to think about the intellectual meaning of "having a point" (a valid argument). The punchline then cleverly shifts to the literal, physical "points" of the triangular samosa, creating a surprising and silly connection between the food item and its argumentative prowess. It\'s a classic example of a pun, where the unexpected literal interpretation of a word creates the comedic effect.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'samosa'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632dc-b80a-6ffa-8000-a63969dc4c6b'}}, metadata={'source': 'update', 'step': 0, 'parents': {}}, created_at='2026-06-08T11:32:56.408268+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f06cc6e-7232-6cb1-8000-f71609e6cec5'}}, tasks=(PregelTask(id='7fbb4eba-114d-13ef-1c74-d98ff00dffc5', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error="ConnectError('[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)')", interrupts=(), state=None, result={'joke': 'Why are samosas so good at arguments?\n\nBecause they always have a **point**!'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza maker break up with the cheese?\n\nBecause he thought it was too *cheesy*!', 'explanation': 'This joke is a classic example of a **pun**, which relies on a word having two different meanings.\n\nHere\'s the breakdown:\n\n1.  **Meaning 1 (Literal - related to pizza):** When we talk about food, "cheesy" literally means something contains a lot of cheese or has a strong cheese flavor. A pizza maker would definitely deal with a lot of literal cheese.\n\n2.  **Meaning 2 (Figurative/Slang):** "Cheesy" is also a slang term used to describe something that is corny, unoriginal, overly sentimental, tacky, or trying too hard to be funny or impressive (often in a cringey way).\n\n**How the joke works:**\n\n*   The setup ("Why did the pizza maker break up with the cheese?") makes you think about the *literal* cheese used on a pizza. You expect a reason related to its taste, texture, or quantity.\n*   The punchline ("Because he thought it was too *cheesy*!") uses the *slang* meaning. The humor comes from the unexpected twist of applying a human characteristic (being "corny" or "tacky") to an inanimate object like cheese, as if the cheese itself had a personality that was annoying or unoriginal.\n\nSo, the joke is funny because it plays on the double meaning of "cheesy," tricking your brain into expecting one meaning and then delivering the punchline with the other.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632d8-63d4-653c-8005-45330c43005e'}}, metadata={'source': 'loop', 'step': 5, 'parents': {}}, created_at='2026-06-08T11:31:00.203654+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632d8-1e86-6bab-8004-64060f6e662c'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza maker break up with the cheese?\n\nBecause he thought it was too *cheesy*!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632d8-1e86-6bab-8004-64060f6e662c'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-06-08T11:30:52.936695+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632d6-bd43-6dd0-8003-791f938d2665'}}, tasks=(PregelTask(id='8dc5c706-e56e-f804-874f-775b01ff26a6', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a classic example of a **pun**, which relies on a word having two different meanings.\n\nHere\'s the breakdown:\n\n1.  **Meaning 1 (Literal - related to pizza):** When we talk about food, "cheesy" literally means something contains a lot of cheese or has a strong cheese flavor. A pizza maker would definitely deal with a lot of literal cheese.\n\n2.  **Meaning 2 (Figurative/Slang):** "Cheesy" is also a slang term used to describe something that is corny, unoriginal, overly sentimental, tacky, or trying too hard to be funny or impressive (often in a cringey way).\n\n**How the joke works:**\n\n*   The setup ("Why did the pizza maker break up with the cheese?") makes you think about the *literal* cheese used on a pizza. You expect a reason related to its taste, texture, or quantity.\n*   The punchline ("Because he thought it was too *cheesy*!") uses the *slang* meaning. The humor comes from the unexpected twist of applying a human characteristic (being "corny" or "tacky") to an inanimate object like cheese, as if the cheese itself had a personality that was annoying or unoriginal.\n\nSo, the joke is funny because it plays on the double meaning of "cheesy," tricking your brain into expecting one meaning and then delivering the punchline with the other.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632d6-bd43-6dd0-8003-791f938d2665'}}, metadata={'source': 'fork', 'step': 3, 'parents': {}}, created_at='2026-06-08T11:30:15.894574+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aaa-69a5-8002-b6c8e82bc627'}}, tasks=(PregelTask(id='66c59019-2594-d0ab-6886-37901855e94c', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza maker break up with the cheese?\n\nBecause he thought it was too *cheesy*!'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\nBecause it kneaded the dough!', 'explanation': 'This joke is a pun that plays on the similar sound of two phrases:\n\n1.  **"Kneaded the dough" (literal pizza making):**\n    *   **"Kneaded"** (pronounced "need-ed") refers to the physical act of working and pressing pizza dough with your hands to develop its texture.\n    *   **"Dough"** is the raw mixture that makes up the pizza crust.\n    *   So, a pizza literally "kneads its dough" when it\'s being made.\n\n2.  **"Needed the dough" (slang for needing money):**\n    *   **"Needed"** (sounds exactly like "kneaded") means to require something.\n    *   **"Dough"** is a common slang term for **money**.\n    *   So, if someone "needed the dough," it means they needed money.\n\n**The Punchline Explained:**\n\nThe joke asks "Why did the pizza get a job?" Jobs are for earning money. The answer, "Because it kneaded the dough," sounds like "Because it *needed the money*." The humor comes from the unexpected twist of applying a literal pizza-making term to a very human reason for getting a job, using the wordplay between "kneaded" and "needed," and "dough" (pizza) and "dough" (money).'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c4-3224-6a2a-8004-b95345a76ef5'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-06-08T11:21:58.122756+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-f591-619c-8003-36c94e13dd93'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza get a job?\nBecause it kneaded the dough!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-f591-619c-8003-36c94e13dd93'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-06-08T11:21:51.770870+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aaa-69a5-8002-b6c8e82bc627'}}, tasks=(PregelTask(id='693dcb1e-7879-fb5d-c5e8-e3c568430693', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a pun that plays on the similar sound of two phrases:\n\n1.  **"Kneaded the dough" (literal pizza making):**\n    *   **"Kneaded"** (pronounced "need-ed") refers to the physical act of working and pressing pizza dough with your hands to develop its texture.\n    *   **"Dough"** is the raw mixture that makes up the pizza crust.\n    *   So, a pizza literally "kneads its dough" when it\'s being made.\n\n2.  **"Needed the dough" (slang for needing money):**\n    *   **"Needed"** (sounds exactly like "kneaded") means to require something.\n    *   **"Dough"** is a common slang term for **money**.\n    *   So, if someone "needed the dough," it means they needed money.\n\n**The Punchline Explained:**\n\nThe joke asks "Why did the pizza get a job?" Jobs are for earning money. The answer, "Because it kneaded the dough," sounds like "Because it *needed the money*." The humor comes from the unexpected twist of applying a literal pizza-making term to a very human reason for getting a job, using the wordplay between "kneaded" and "needed," and "dough" (pizza) and "dough" (money).'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aaa-69a5-8002-b6c8e82bc627'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-06-08T11:21:42.239274+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aa4-6c48-8001-ac7f09cff08d'}}, tasks=(PregelTask(id='dc527f0b-8538-02be-6a9d-a0bd93250f30', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza get a job?\nBecause it kneaded the dough!'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c3-9aa4-6c48-8001-ac7f09cff08d'}}, metadata={'source': 'input', 'step': 1, 'parents': {}}, created_at='2026-06-08T11:21:42.236884+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c1-b488-638e-8000-27d7116c585a'}}, tasks=(PregelTask(id='f93b3b1a-8278-9415-0952-41923b4320ef', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c1-b488-638e-8000-27d7116c585a'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-06-08T11:20:51.264398+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c1-b483-653e-bfff-3bd1f78a4f51'}}, tasks=(PregelTask(id='d17fdd74-3868-56db-21db-91a1b206877c', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error="ConnectError('[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)')", interrupts=(), state=None, result=None),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1632c1-b483-653e-bfff-3bd1f78a4f51'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-06-08T11:20:51.262393+00:00', parent_config=None, tasks=(PregelTask(id='a270c772-0242-cd1c-6d97-3f4c32f5bd98', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %% [markdown]
# fault tolerance

# %%
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import InMemorySaver
from typing import TypedDict
import time

# %%
# Define the State
class CrashState(TypedDict):
    input: str
    step1: str
    step2: str

# %%
# Define the steps
def step_1(state: CrashState) -> CrashState:
    print("step1 executed")
    return {"step1":"done", "input": state["input"]}

def step_2(state: CrashState)->CrashState:
    print("Step2 hanging... now manually interrupt from the notebook toolbar(STOP button)")
    time.sleep(1000)
    return {"step2":"done"}

def step_3(state: CrashState) -> CrashState:
    print("step3 executed")
    return {"done": True}

# %%
# 3. Build the graph
builder = StateGraph(CrashState)
builder.add_node("step_1",step_1)
builder.add_node("step_2", step_2)
builder.add_node("step_3", step_3)

builder.set_entry_point("step_1")
builder.add_edge("step_1", "step_2")
builder.add_edge("step_2", "step_3")
builder.add_edge("step_3", END)

checkpointer = InMemorySaver()
graph = builder.compile(checkpointer=checkpointer)

# %%
try:
    print("Running graph: Please manually interrupt during step2...")
    graph.invoke({"input":"start"}, config={"configurable":{"thread_id": 'thread-1'}})
except KeyboardInterrupt:
    print("Kernel manually interrupted (crash simumlated).")
# Out:
# Running graph: Please manually interrupt during step2...
# step1 executed
# Step2 hanging... now manually interrupt from the notebook toolbar(STOP button)

# %%
# 6. Re-run to show fault-tolerant resume
print("\n🔁 Re-running the graph to demonstrate fault tolerance...")
final_state = graph.invoke(None, config={"configurable": {"thread_id": 'thread-1'}})
print("\n✅ Final State:", final_state)

# %%
list(graph.get_state_history({"configurable": {"thread_id": 'thread-1'}}))
