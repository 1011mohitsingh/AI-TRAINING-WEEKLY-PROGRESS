# %% [markdown]
# # Pandas Series - videos refered on youtube by shreyiansAI
# A Series is a one-dimensional labeled array capable of holding any data type. The axis labels are collectively called the index.
# # Creating Series
# There are multiple ways to create a pandas Series
# ### flow
# Series, Data Frames, MIssing Data, (Merging,joining, concatenation),

# %%
# %pip install pandas
import numpy as np
import pandas as pd
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
labels = ['a','b','c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {'a':10, 'b':20, 'c':30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %% [markdown]
# Labels are nothing but the index you can say and in the pandas the data points come in the vertical way okkay. Also we can give their own indexes as well apart from what is created 0,1,2

# %%
pd.Series(my_list, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %% [markdown]
# If we send the 2d dimensional data so it will throw an error and that is because series is capable of holding one dimensional data thats why

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64
